# %%
# %matplotlib inline
import pandas as pd
data_info=pd.read_csv("Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv")
data_info
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc  \
# 0           2011     2011           AL      Alabama
# 1           2011     2011           AL      Alabama
# 2           2011     2011           AL      Alabama
# 3           2011     2011           AL      Alabama
# 4           2011     2011           AL      Alabama
# 5           2011     2011           AL      Alabama
# 6           2011     2011           AL      Alabama
# 7           2011     2011           AL      Alabama
# 8           2011     2011           AL      Alabama
# 9           2011     2011           AL      Alabama
# 10          2011     2011           AL      Alabama
# 11          2011     2011           AL      Alabama
# 12          2011     2011           AL      Alabama
# 13          2011     2011           AL      Alabama
# 14          2011     2011           AL      Alabama
# 15          2011     2011           AL      Alabama
# 16          2011     2011           AL      Alabama
# ...

# %%
data_info.head(4)
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2011     2011           AL      Alabama
# 1       2011     2011           AL      Alabama
# 2       2011     2011           AL      Alabama
# 3       2011     2011           AL      Alabama
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 2  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# ...

# %%
df = pd.DataFrame(data_info, columns = ['yearStart', 'YearEnd', 'LocationAbbr', 'StratificationCategoryId1'])
df
# Out:
#        yearStart  YearEnd LocationAbbr StratificationCategoryId1
# 0            NaN     2011           AL                       OVR
# 1            NaN     2011           AL                       GEN
# 2            NaN     2011           AL                       GEN
# 3            NaN     2011           AL                       EDU
# 4            NaN     2011           AL                       EDU
# 5            NaN     2011           AL                       EDU
# 6            NaN     2011           AL                       EDU
# 7            NaN     2011           AL                     AGEYR
# 8            NaN     2011           AL                     AGEYR
# 9            NaN     2011           AL                     AGEYR
# 10           NaN     2011           AL                     AGEYR
# 11           NaN     2011           AL                     AGEYR
# 12           NaN     2011           AL                     AGEYR
# ...

# %%
df['YearEnd'].mean()
# Out:
# 2012.2595541401274

# %%
df['YearEnd'].describe()
# Out:
# count    35168.000000
# mean      2012.259554
# std          1.093346
# min       2011.000000
# 25%       2011.000000
# 50%       2013.000000
# 75%       2013.000000
# max       2014.000000
# Name: YearEnd, dtype: float64

# %%
df['YearEnd'].var()
# Out:
# 1.1954044931022039

# %%
df.corr()
# Out:
#            yearStart  YearEnd
# yearStart        NaN      NaN
# YearEnd          NaN      1.0

# %%
df.cov()
# Out:
#            yearStart   YearEnd
# yearStart        NaN       NaN
# YearEnd          NaN  1.195404

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-41f6e60748c1> in <module>()
#       1 df = pd.DataFrame(columns=['yearStart', 'yearEnd', 'Location'])
# ----> 2 df.plot.box()
#
# /anaconda/lib/python3.6/site-packages/pandas/tools/plotting.py in box(self, by, **kwds)
#    3849         axes : matplotlib.AxesSubplot or np.array of them
#    3850         """
# -> 3851         return self(kind='box', by=by, **kwds)
#    3852
#    3853     def hist(self, by=None, bins=10, **kwds):
#
# /anaconda/lib/python3.6/site-packages/pandas/tools/plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
# ...
