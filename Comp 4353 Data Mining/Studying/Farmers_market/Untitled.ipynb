# %%
# got the data from https://www.data.gov

import pandas as pd 

farm_info=pd.read_csv("Farmers_Markets_-_2015.csv")

# %%
print(type(farm_info))
farm_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                              LOCATION  \
# 0                                 Pilsen Night Market
# 1                                       Columbus Park
# 2                                         Northcenter
# 3                                        Printers Row
# 4            Garfield Park (Monthly on 2nd Saturdays)
# 5            Garfield Park (Monthly on 3rd Thursdays)
# 6                                      Lincoln Square
# 7                                     Division Street
# 8                                    La Follette Park
# 9                                        Lincoln Park
# 10                                   Austin Town Hall
# 11                                        Daley Plaza
# 12                                      Federal Plaza
# 13                                            Pullman
# 14                                 Willis Tower Plaza
# 15                                 West Humboldt Park
# ...

# %%
# To select the first 5 rows of a dataframe, use the dataframe method head()
first_rows=farm_info.head()
first_rows
# Out:
#                                    LOCATION                 INTERSECTION  \
# 0                       Pilsen Night Market  18th St. & Blue Island Ave.
# 1                             Columbus Park           Harrison & Central
# 2                               Northcenter       Lincoln & Belle Plaine
# 3                              Printers Row              Dearborn & Polk
# 4  Garfield Park (Monthly on 2nd Saturdays)                Lake & Kedzie
#
#          DAY START TIME END TIME  START DATE    END DATE  \
# 0  Wednesday    4:00 PM  8:00 PM  07/08/2015  09/02/2015
# 1    Tuesday    2:00 PM  7:00 PM  06/30/2015  09/29/2015
# 2   Saturday    7:00 AM  1:00 PM  06/13/2015  10/24/2015
# 3   Saturday    7:00 AM  1:00 PM  06/20/2015  10/24/2015
# 4   Saturday   10:00 AM  1:00 PM  06/13/2015  10/10/2015
#
#                            WEBSITE          TYPE LINK ACCEPTED   LATITUDE  \
# 0  http://chicagofarmersmarkets.us  Neighborhood             Y  41.857866
# ...

# %%
# Also we can pass an integer as well on our head() method 

head_info=farm_info.head(4)
head_info
# Out:
#               LOCATION                 INTERSECTION        DAY START TIME  \
# 0  Pilsen Night Market  18th St. & Blue Island Ave.  Wednesday    4:00 PM
# 1        Columbus Park           Harrison & Central    Tuesday    2:00 PM
# 2          Northcenter       Lincoln & Belle Plaine   Saturday    7:00 AM
# 3         Printers Row              Dearborn & Polk   Saturday    7:00 AM
#
#   END TIME  START DATE    END DATE                          WEBSITE  \
# 0  8:00 PM  07/08/2015  09/02/2015  http://chicagofarmersmarkets.us
# 1  7:00 PM  06/30/2015  09/29/2015  http://chicagofarmersmarkets.us
# 2  1:00 PM  06/13/2015  10/24/2015  http://chicagofarmersmarkets.us
# 3  1:00 PM  06/20/2015  10/24/2015  http://chicagofarmersmarkets.us
#
#            TYPE LINK ACCEPTED   LATITUDE  LONGITUDE  \
# 0  Neighborhood             Y  41.857866 -87.661159
# 1  Neighborhood             Y  41.872636 -87.765010
# 2  Neighborhood             Y  41.955976 -87.679102
# ...

# %%
column_names=farm_info.columns

# %%
column_names
# Out:
# Index(['LOCATION', 'INTERSECTION', 'DAY', 'START TIME', 'END TIME',
#        'START DATE', 'END DATE', 'WEBSITE', 'TYPE', 'LINK ACCEPTED',
#        'LATITUDE', 'LONGITUDE', 'MAP'],
#       dtype='object')

# %%
# We can use shape attribute to understand the dimensions of the dataframe.

dimension=farm_info.shape

# %%
dimension
# Out:
# (47, 13)

# %%
num_rows =dimension[0]
num_rows
# Out:
# 47

# %%
num_cols = dimension[1]
num_cols
# Out:
# 13

# %%
print(farm_info.head(3))
# Out:
#               LOCATION                 INTERSECTION        DAY START TIME  \
# 0  Pilsen Night Market  18th St. & Blue Island Ave.  Wednesday    4:00 PM
# 1        Columbus Park           Harrison & Central    Tuesday    2:00 PM
# 2          Northcenter       Lincoln & Belle Plaine   Saturday    7:00 AM
#
#   END TIME  START DATE    END DATE                          WEBSITE  \
# 0  8:00 PM  07/08/2015  09/02/2015  http://chicagofarmersmarkets.us
# 1  7:00 PM  06/30/2015  09/29/2015  http://chicagofarmersmarkets.us
# 2  1:00 PM  06/13/2015  10/24/2015  http://chicagofarmersmarkets.us
#
#            TYPE LINK ACCEPTED   LATITUDE  LONGITUDE  \
# 0  Neighborhood             Y  41.857866 -87.661159
# 1  Neighborhood             Y  41.872636 -87.765010
# 2  Neighborhood             Y  41.955976 -87.679102
#
#                            MAP
# 0    (41.8578656, -87.6611589)
# 1  (41.87263635, -87.76501013)
# 2  (41.95597563, -87.67910157)

# %%
dimension = farm_info.shape
print(dimension)
# Out:
# (47, 13)

# %%
num_rows = dimension[0]
print(num_rows)
# Out:
# 47

# %%
num_cols = dimension[1]
print(num_cols)
# Out:
# 13

# %%
first_twenty=farm_info.head(20)
print (first_twenty)
# Out:
#                                     LOCATION  \
# 0                        Pilsen Night Market
# 1                              Columbus Park
# 2                                Northcenter
# 3                               Printers Row
# 4   Garfield Park (Monthly on 2nd Saturdays)
# 5   Garfield Park (Monthly on 3rd Thursdays)
# 6                             Lincoln Square
# 7                            Division Street
# 8                           La Follette Park
# 9                               Lincoln Park
# 10                          Austin Town Hall
# 11                               Daley Plaza
# 12                             Federal Plaza
# 13                                   Pullman
# 14                        Willis Tower Plaza
# 15                        West Humboldt Park
# 16                            Near West Side
# 17                   Englewood/ Anchor House
# 18                                 Ford City
# 19                               Bronzeville
#
# ...
